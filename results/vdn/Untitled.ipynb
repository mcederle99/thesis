# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.load('time_steps_2h.npy')
scores = np.load('VDN_2h.npy')

# %%
fig = plt.figure()
ax = fig.add_subplot(111, label="1")

N = len(scores)
print(N)
running_avg = np.empty(N)
for t in range(N):
    running_avg[t] = np.mean(
            scores[max(0, t-2):(t+1)])

ax.plot(x, running_avg, color="C0")
ax.set_xlabel("Training Steps", color="C0")
ax.set_ylabel("Avg. Return VDN", color="C0")
ax.tick_params(axis='x', colors="C0")
ax.tick_params(axis='y', colors="C0")
plt.grid(True, axis='y', linestyle=':')
plt.show()
# Out:
# 101

# %% [markdown]
# Punteggio basso perché quando lo scenario finisce uno dei due veicoli ha fatto poca strada dopo essere ripartito dall'incrocio
