# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.load('duelingddqn_3h_shared_steps.npy')
scores = np.load('duelingddqn_3h_shared_scores.npy')

# %%
fig = plt.figure()
ax = fig.add_subplot(111, label="1")

N = len(scores)
#print(N)
#running_avg = np.empty(N)
#for t in range(N):
#    running_avg[t] = np.mean(
#            scores[max(0, t-100):(t+1)])

ax.plot(x, scores, color="C0")
ax.set_xlabel("Training Steps", color="C0")
ax.set_ylabel("Avg. Return MADDPG", color="C0")
ax.tick_params(axis='x', colors="C0")
ax.tick_params(axis='y', colors="C0")
plt.grid(True, axis='y', linestyle=':')
#plt.savefig('maddpg2h.png')
